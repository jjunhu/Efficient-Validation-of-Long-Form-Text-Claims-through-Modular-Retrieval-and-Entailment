# %%
import pandas as pd
import json
import requests
from nltk.tokenize import sent_tokenize
import nltk
import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

# Ensure NLTK punkt is downloaded
nltk.download('punkt')

# Function to generate a URL for a specific book
def generate_url(model_size='6b', book_num=0):
    return f"https://openaipublic.blob.core.windows.net/recursive-book-summ/website/data/booksum_book_trees/{model_size}/{book_num}/all.json"

# Function to scrape data from a URL
def scrape_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        return json.loads(response.content)
    else:
        return None
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jonathanhu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Function to process a book and map summaries to text
def process_book(model_size, book_num):
    url = generate_url(model_size, book_num)
    data = scrape_data(url)
    if data is None or "3" not in data:
        return []
    
    mapped_summaries = []
    
    for entry in data["3"]:
        summary_sentences = sent_tokenize(entry["summary"])
        idx = 0
        for sentence in summary_sentences:
            mapped_summaries.append({
                "model_size": model_size,
                "book_num": book_num,
                "summary_sentence_num": idx,
                "summary_sentence": sentence,
                "text_chunk": entry["text"]
            })    
            idx += 1
    return mapped_summaries

# Function to process books in parallel
def process_books_parallel(model_sizes, book_nums):
    all_mappings = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(process_book, model_size, book_num) for model_size in model_sizes for book_num in book_nums]
        for future in tqdm.tqdm(as_completed(futures), total=len(futures), desc="Processing Books"):
            all_mappings.extend(future.result())
    
    return all_mappings

# %%
model_sizes = ['175b']
book_nums = list(range(268))

all_mappings = process_books_parallel(model_sizes, book_nums)

# Convert to DataFrame
df = pd.DataFrame(all_mappings)

df
# Out:
# Processing Books: 100%|██████████| 268/268 [00:27<00:00,  9.72it/s]
#        model_size  book_num  summary_sentence_num  \
# 0            175b         9                     0
# 1            175b         9                     1
# 2            175b         9                     2
# 3            175b         9                     3
# 4            175b         9                     4
# ...           ...       ...                   ...
# 217891       175b       264                     2
# 217892       175b       264                     3
# 217893       175b       264                     4
# 217894       175b       264                     5
# 217895       175b       264                     6
#
#                                          summary_sentence  \
# 0       The narrator was born in a small town in Georg...
# 1       He has a faint recollection of his birthplace,...
# 2       He remembers playing in the sand and digging u...
# 3       He also remembers a cow in an enclosure, and h...
# 4       He only has a few memories of the people who l...
# ...                                                   ...
# 217891  Doyce then comes in and tells Clennam that he ...
# 217892  The next day, Little Dorrit visits the prison ...
# 217893  They quietly walk along the yard, and are marr...
# 217894  After the signing of the marriage register, th...
# 217895  They go down to give a mother's care to Fanny'...
#
#                                                text_chunk
# 0       \n\nI know that in writing the following pages...
# 1       \n\nI know that in writing the following pages...
# 2       \n\nI know that in writing the following pages...
# 3       \n\nI know that in writing the following pages...
# 4       \n\nI know that in writing the following pages...
# ...                                                   ...
# 217891  Mr. F.'s Aunt holds out like a fortress, and F...
# 217892  Mr. F.'s Aunt holds out like a fortress, and F...
# 217893  Mr. F.'s Aunt holds out like a fortress, and F...
# 217894  Mr. F.'s Aunt holds out like a fortress, and F...
# 217895  Mr. F.'s Aunt holds out like a fortress, and F...
#
# [217896 rows x 5 columns]

# %%
# Sort the dataframe by 'book_num' in ascending order while preserving the original order of 'summary_sentence_num'
df_sorted = df.sort_values(by=['book_num', 'summary_sentence_num']).reset_index(drop=True)

# Update 'summary_sentence_num' to increment for each 'book_num'
df_sorted['summary_sentence_num'] = df_sorted.groupby('book_num').cumcount()

# Save the updated dataframe to a new CSV file
df_sorted.to_csv("mapped_summaries_l3.csv", index=False)

df_sorted
# Out:
#        model_size  book_num  summary_sentence_num  \
# 0            175b         0                     0
# 1            175b         0                     1
# 2            175b         0                     2
# 3            175b         0                     3
# 4            175b         0                     4
# ...           ...       ...                   ...
# 217891       175b       266                  1717
# 217892       175b       266                  1718
# 217893       175b       266                  1719
# 217894       175b       266                  1720
# 217895       175b       266                  1721
#
#                                          summary_sentence  \
# 0       Uncle Pros is helping Laurella, his sick niece...
# 1       Laurella explains that her husband, Consadine,...
# 2       Pros takes the cradle outside to get the last ...
# 3       Mavity sends Bud and Mandy Ann to ask her fath...
# 4       Pros finishes repairing the cradle and places ...
# ...                                                   ...
# 217891      Men of business may speak to Mr. Darnay now?"
# 217892                                Carton replies that
# 217893                                  Mr. Lorry notices
# 217894                        I have seen it many times."
# 217895  The wind is rushing after them, and the clouds...
#
#                                                text_chunk
# 0       THE BIRTH OF A WOMAN-CHILD\n\n"Whose cradle's ...
# 1       selfish--said she'd like to know how I was goi...
# 2       rich, broken light from the cavernous fireplac...
# 3       \n"Well, you go ask Pap to look in the green c...
# 4       she wants--ain't ye, Pretty?"\n\nAnd, having m...
# ...                                                   ...
# 217891  Darnay: an intent look, deepening into a frown...
# 217892  \n"I don't gainsay it. What has roughened your...
# 217893  it, to know that it teems with interest; littl...
# 217894  linked hand in hand, and all spun round togeth...
# 217895  the little street, bereft of horses, and with ...
#
# [217896 rows x 5 columns]
